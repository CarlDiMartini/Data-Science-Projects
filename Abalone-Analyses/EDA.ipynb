# %% [markdown]
# # EDA

# %% [markdown]
# &nbsp;

# %% [markdown]
# ### <i><b>Companion to [Abalone Analysis](https://github.com/CarlDiMartini/Data-Science-Projects/blob/main/Abalone-Analyses/Abalone%20Analysis.ipynb).<b><i>

# %% [markdown]
# ### <i><b>Notebook by Carl Di Martini<b>

# %% [markdown]
# &nbsp;

# %% [markdown]
# ![abalone.jpg](attachment:abalone.jpg)

# %% [markdown]
# &nbsp;

# %% [markdown]
# ### 1. Data Fields:

# %% [markdown]
# * Sex - M, F, and I-infant<br />
# * Length of Shell-mm (longest)<br />
# * Diameter-mm (perpendicular to longest)<br />
# * Height-mm (shell with meat)<br />
# * Whole-g (entire specimen)<br />
# * Shucked-g (meat)<br />
# * Viscera-g (gut after bleeding)<br />
# * Shell-g (dry)<br />
# * Rings Count<br />

# %% [markdown]
# ### 2. Importing Packages and General Setup:

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from matplotlib import rcParams
sns.set(style="darkgrid")
plt.style.use('ggplot')

# %%
data = pd.read_csv('abalone.data', header = None)

# %% [markdown]
# ### 3. A Cursory View of the Data:

# %% [markdown]
# The data set comes with a brief description of each field.  That the 'Length of Shell...' should be the longest length measurement, will come up later in the data sanity checks.

# %%
data.columns = ['Sex (M, F, and I-infant)', 'Length of Shell-mm (longest)',
                'Diameter-mm (perpendicular to longest)', 'Height-mm (shell with meat)',
                'Whole-g (entire specimen)', 'Shucked-g (meat)',
                'Viscera-g (gut after bleeding)', 'Shell-g (dry)',
                'Rings Count']

# %%
data.head().style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_0ab64f00_a92b_11eb_9c7b_502f9bedf95d" ><thead>    <tr>        <th class="col_heading level0 col0" >Sex (M, F, and I-infant)</th>        <th class="col_heading level0 col1" >Length of Shell-mm (longest)</th>        <th class="col_heading level0 col2" >Diameter-mm (perpendicular to longest)</th>        <th class="col_heading level0 col3" >Height-mm (shell with meat)</th>        <th class="col_heading level0 col4" >Whole-g (entire specimen)</th>        <th class="col_heading level0 col5" >Shucked-g (meat)</th>        <th class="col_heading level0 col6" >Viscera-g (gut after bleeding)</th>        <th class="col_heading level0 col7" >Shell-g (dry)</th>        <th class="col_heading level0 col8" >Rings Count</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_0ab64f00_a92b_11eb_9c7b_502f9bedf95drow0_col0" class="data row0 col0" >M</td>
#                         <td id="T_0ab64f00_a92b_11eb_9c7b_502f9bedf95drow0_col1" class="data row0 col1" >0.455000</td>
#                         <td id="T_0ab64f00_a92b_11eb_9c7b_502f9bedf95drow0_col2" class="data row0 col2" >0.365000</td>
#                         <td id="T_0ab64f00_a92b_11eb_9c7b_502f9bedf95drow0_col3" class="data row0 col3" >0.095000</td>
#                         <td id="T_0ab64f00_a92b_11eb_9c7b_502f9bedf95drow0_col4" class="data row0 col4" >0.514000</td>
#                         <td id="T_0ab64f00_a92b_11eb_9c7b_502f9bedf95drow0_col5" class="data row0 col5" >0.224500</td>
#                         <td id="T_0ab64f00_a92b_11eb_9c7b_502f9bedf95drow0_col6" class="data row0 col6" >0.101000</td>
#                         <td id="T_0ab64f00_a92b_11eb_9c7b_502f9bedf95drow0_col7" class="data row0 col7" >0.150000</td>
#                         <td id="T_0ab64f00_a92b_11eb_9c7b_502f9bedf95drow0_col8" class="data row0 col8" >15</td>
#             </tr>
#             <tr>
#                                 <td id="T_0ab64f00_a92b_11eb_9c7b_502f9bedf95drow1_col0" class="data row1 col0" >M</td>
#                         <td id="T_0ab64f00_a92b_11eb_9c7b_502f9bedf95drow1_col1" class="data row1 col1" >0.350000</td>
#                         <td id="T_0ab64f00_a92b_11eb_9c7b_502f9bedf95drow1_col2" class="data row1 col2" >0.265000</td>
#                         <td id="T_0ab64f00_a92b_11eb_9c7b_502f9bedf95drow1_col3" class="data row1 col3" >0.090000</td>
#                         <td id="T_0ab64f00_a92b_11eb_9c7b_502f9bedf95drow1_col4" class="data row1 col4" >0.225500</td>
#                         <td id="T_0ab64f00_a92b_11eb_9c7b_502f9bedf95drow1_col5" class="data row1 col5" >0.099500</td>
#                         <td id="T_0ab64f00_a92b_11eb_9c7b_502f9bedf95drow1_col6" class="data row1 col6" >0.048500</td>
#                         <td id="T_0ab64f00_a92b_11eb_9c7b_502f9bedf95drow1_col7" class="data row1 col7" >0.070000</td>
#                         <td id="T_0ab64f00_a92b_11eb_9c7b_502f9bedf95drow1_col8" class="data row1 col8" >7</td>
#             </tr>
#             <tr>
#                                 <td id="T_0ab64f00_a92b_11eb_9c7b_502f9bedf95drow2_col0" class="data row2 col0" >F</td>
#                         <td id="T_0ab64f00_a92b_11eb_9c7b_502f9bedf95drow2_col1" class="data row2 col1" >0.530000</td>
#                         <td id="T_0ab64f00_a92b_11eb_9c7b_502f9bedf95drow2_col2" class="data row2 col2" >0.420000</td>
#                         <td id="T_0ab64f00_a92b_11eb_9c7b_502f9bedf95drow2_col3" class="data row2 col3" >0.135000</td>
#                         <td id="T_0ab64f00_a92b_11eb_9c7b_502f9bedf95drow2_col4" class="data row2 col4" >0.677000</td>
#                         <td id="T_0ab64f00_a92b_11eb_9c7b_502f9bedf95drow2_col5" class="data row2 col5" >0.256500</td>
#                         <td id="T_0ab64f00_a92b_11eb_9c7b_502f9bedf95drow2_col6" class="data row2 col6" >0.141500</td>
#                         <td id="T_0ab64f00_a92b_11eb_9c7b_502f9bedf95drow2_col7" class="data row2 col7" >0.210000</td>
#                         <td id="T_0ab64f00_a92b_11eb_9c7b_502f9bedf95drow2_col8" class="data row2 col8" >9</td>
#             </tr>
#             <tr>
#                                 <td id="T_0ab64f00_a92b_11eb_9c7b_502f9bedf95drow3_col0" class="data row3 col0" >M</td>
#                         <td id="T_0ab64f00_a92b_11eb_9c7b_502f9bedf95drow3_col1" class="data row3 col1" >0.440000</td>
#                         <td id="T_0ab64f00_a92b_11eb_9c7b_502f9bedf95drow3_col2" class="data row3 col2" >0.365000</td>
#                         <td id="T_0ab64f00_a92b_11eb_9c7b_502f9bedf95drow3_col3" class="data row3 col3" >0.125000</td>
#                         <td id="T_0ab64f00_a92b_11eb_9c7b_502f9bedf95drow3_col4" class="data row3 col4" >0.516000</td>
#                         <td id="T_0ab64f00_a92b_11eb_9c7b_502f9bedf95drow3_col5" class="data row3 col5" >0.215500</td>
#                         <td id="T_0ab64f00_a92b_11eb_9c7b_502f9bedf95drow3_col6" class="data row3 col6" >0.114000</td>
#                         <td id="T_0ab64f00_a92b_11eb_9c7b_502f9bedf95drow3_col7" class="data row3 col7" >0.155000</td>
#                         <td id="T_0ab64f00_a92b_11eb_9c7b_502f9bedf95drow3_col8" class="data row3 col8" >10</td>
#             </tr>
#             <tr>
#                                 <td id="T_0ab64f00_a92b_11eb_9c7b_502f9bedf95drow4_col0" class="data row4 col0" >I</td>
#                         <td id="T_0ab64f00_a92b_11eb_9c7b_502f9bedf95drow4_col1" class="data row4 col1" >0.330000</td>
#                         <td id="T_0ab64f00_a92b_11eb_9c7b_502f9bedf95drow4_col2" class="data row4 col2" >0.255000</td>
#                         <td id="T_0ab64f00_a92b_11eb_9c7b_502f9bedf95drow4_col3" class="data row4 col3" >0.080000</td>
#                         <td id="T_0ab64f00_a92b_11eb_9c7b_502f9bedf95drow4_col4" class="data row4 col4" >0.205000</td>
#                         <td id="T_0ab64f00_a92b_11eb_9c7b_502f9bedf95drow4_col5" class="data row4 col5" >0.089500</td>
#                         <td id="T_0ab64f00_a92b_11eb_9c7b_502f9bedf95drow4_col6" class="data row4 col6" >0.039500</td>
#                         <td id="T_0ab64f00_a92b_11eb_9c7b_502f9bedf95drow4_col7" class="data row4 col7" >0.055000</td>
#                         <td id="T_0ab64f00_a92b_11eb_9c7b_502f9bedf95drow4_col8" class="data row4 col8" >7</td>
#             </tr>
#     </tbody></table>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Sex (M, F, and I-infant)                4177 non-null   object
#  1   Length of Shell-mm (longest)            4177 non-null   float64
#  2   Diameter-mm (perpendicular to longest)  4177 non-null   float64
#  3   Height-mm (shell with meat)             4177 non-null   float64
#  4   Whole-g (entire specimen)               4177 non-null   float64
#  5   Shucked-g (meat)                        4177 non-null   float64
#  6   Viscera-g (gut after bleeding)          4177 non-null   float64
#  7   Shell-g (dry)                           4177 non-null   float64
#  8   Rings Count                             4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %%
data.iloc[:,0].unique()
# Out:
# array(['M', 'F', 'I'], dtype=object)

# %%
data.isnull().sum()
# Out:
# Sex (M, F, and I-infant)                  0
# Length of Shell-mm (longest)              0
# Diameter-mm (perpendicular to longest)    0
# Height-mm (shell with meat)               0
# Whole-g (entire specimen)                 0
# Shucked-g (meat)                          0
# Viscera-g (gut after bleeding)            0
# Shell-g (dry)                             0
# Rings Count                               0
# dtype: int64

# %% [markdown]
# &nbsp;

# %% [markdown]
# ### 4. Implications of Infancy:
# If the sex of a given specimen is 'I-infant', does that generally mean fewer rings?

# %%
sex = 'Sex (M, F, and I-infant)'

# %%
fig = plt.figure(figsize=(18, 8))
fig.suptitle("Ring Counts for Sex as 'I', 'F' and 'M'", fontsize=25)
fig.subplots_adjust(hspace=-0.8)
plt.rcParams['axes.facecolor'] = 'white'
plt.rcParams['grid.color'] = 'white'
plt.rcParams['grid.linestyle'] = '-'
plt.rcParams['grid.linewidth'] = 5.0
labels = ["sex = 'I'", "sex = 'F'", "sex = 'M'"]
colors = ['black', 'magenta', 'blue']

for i in range (4,7):
    fig.add_subplot(2,3,i)
    sns.histplot(data[data[sex]=='I']['Rings Count'], color=colors[i-4], label=labels[i-4], zorder=-1)
    plt.legend()
    plt.grid(axis='x')
    plt.xticks(fontsize=20)
    plt.yticks(fontsize=20)

for i in range(4):
    print()

# %% [markdown]
# &nbsp;

# %% [markdown]
# Ring counts bare little or no relationship to infancy, so let's use 'neutral' in its place.  Also, making the sex a categorical variable is desirable.

# %%
data.loc[data[sex]=='I', sex] = 'neutral'

# %%
data.iloc[:,0] = pd.Categorical(data.iloc[:,0])

# %%
data.rename(columns = {sex:'Sex (M, F, and neutral)'}, inplace = True)

# %%
sex = 'Sex (M, F, and neutral)'

# %%
data.columns
# Out:
# Index(['Sex (M, F, and neutral)', 'Length of Shell-mm (longest)',
#        'Diameter-mm (perpendicular to longest)', 'Height-mm (shell with meat)',
#        'Whole-g (entire specimen)', 'Shucked-g (meat)',
#        'Viscera-g (gut after bleeding)', 'Shell-g (dry)', 'Rings Count'],
#       dtype='object')

# %%
data[sex].unique()
# Out:
# ['M', 'F', 'neutral']
# Categories (3, object): ['M', 'F', 'neutral']

# %% [markdown]
# ### 5. Sanity checks

# %% [markdown]
# Sanity checks for this data frame should look at:
#
# 1) The ratio of each measurement to the rings count.<br>
# 2) Measurements in 'mm' taken as a group.<br>
# 3) Measurements in 'g' taken as a group.<br>
#
# In the latter two, certain numerical relationships should arise from a simple reading of column labels.

# %% [markdown]
# &nbsp;

# %% [markdown]
# ### 5.a. Ratios Denominated in Ring Counts:

# %%
lengthR   =  data.iloc[:,1]/data['Rings Count']
diameterR =  data.iloc[:,2]/data['Rings Count']
heightR   =  data.iloc[:,3]/data['Rings Count']
wholeR    =  data.iloc[:,4]/data['Rings Count']
shuckedR  =  data.iloc[:,5]/data['Rings Count']
visceraR  =  data.iloc[:,6]/data['Rings Count']
shellR    =  data.iloc[:,7]/data['Rings Count']

# %%
ratiosDF = pd.DataFrame()
ratiosDF['lengthR']   =  lengthR
ratiosDF['diameterR'] =  diameterR
ratiosDF['heightR']   =  heightR
ratiosDF['wholeR']    =  wholeR
ratiosDF['shuckedR']  =  shuckedR
ratiosDF['visceraR']  =  visceraR
ratiosDF['shellR']    =  shellR
ratiosDF['rings count'] = data['Rings Count']
ratiosDF.head()
# Out:
#     lengthR  diameterR   heightR    wholeR  shuckedR  visceraR    shellR  \
# 0  0.030333   0.024333  0.006333  0.034267  0.014967  0.006733  0.010000
# 1  0.050000   0.037857  0.012857  0.032214  0.014214  0.006929  0.010000
# 2  0.058889   0.046667  0.015000  0.075222  0.028500  0.015722  0.023333
# 3  0.044000   0.036500  0.012500  0.051600  0.021550  0.011400  0.015500
# 4  0.047143   0.036429  0.011429  0.029286  0.012786  0.005643  0.007857
#
#    rings count
# 0           15
# 1            7
# 2            9
# 3           10
# 4            7

# %%
ratiosDF["extra column of 0's"]   =  0
plt.rcParams['axes.facecolor'] = 'white'
plt.rcParams['grid.color'] = 'white'
plt.rcParams['grid.linestyle'] = '-'
plt.rcParams['grid.linewidth'] = 5.0
fig, panes = plt.subplots(nrows=3, ncols=3, figsize=(15,20))
panes[2,2].set_visible(False)
ratiosDF.hist(bins = 10, figsize = (15,20), color = 'black', ax=panes, zorder=-1)
for i in range(3):
    for j in range(3):
        panes[i,j].grid(axis='x')
        panes[i,j].tick_params(axis='x', labelsize=15)
        panes[i,j].tick_params(axis='y', labelsize=20)
ratiosDF.drop("extra column of 0's", axis=1, inplace=True)
plt.show()

# %% [markdown]
# <br>
# <br>

# %%
plt.rcParams['grid.color'] = 'black'
plt.rcParams['grid.linewidth'] = 0.40
fig, axis = plt.subplots(nrows=4, ncols=2, figsize=(15,20))
fig.suptitle('Aforementioned Ratios vs Rings Count', fontsize=25)
fig.subplots_adjust(hspace=0.8)
axis[3, 1].axis('off')

labels_list = ['lengthR (mm)', 'diameterR (mm)', 'heightR (mm)', 'wholeR (g)', 'shuckedR (g)', 'visceraR (g)', \
               'shellR (g)']
colors_list = ['black', 'red', '#ff8c00', '#DEC20B', 'green', 'blue', 'indigo']
iterator = 0
i = 0
j = 0
for value in ratiosDF.columns[:-1]:
    axis[i,j].set_title(labels_list[iterator])
    axis[i,j].set_xlabel("ring count")
    plt.sca(axis[i][j])
    plt.scatter(ratiosDF['rings count'], ratiosDF[value], color = colors_list[iterator], label = labels_list[iterator])
    plt.legend()
    
    iterator += 1
    j = iterator%2
    i = iterator//2
    
for i in range(4):
    print()

# %% [markdown]
# &nbsp;

# %% [markdown]
# These plots show a plausible narrative that the growth of the organism in net measurements starts out slow, accelerates and then tails off.  The possibility still remains for bad data, especially in the height category, not to mention sanity checks in other columns.

# %% [markdown]
# &nbsp;

# %% [markdown]
# Let's give short hand variable names for the measurements in 'Data':

# %% [markdown]
# &nbsp;

# %%
data.head(0)
# Out:
# Empty DataFrame
# Columns: [Sex (M, F, and neutral), Length of Shell-mm (longest), Diameter-mm (perpendicular to longest), Height-mm (shell with meat), Whole-g (entire specimen), Shucked-g (meat), Viscera-g (gut after bleeding), Shell-g (dry), Rings Count]
# Index: []

# %%
length   = 'Length of Shell-mm (longest)'
diameter = 'Diameter-mm (perpendicular to longest)'
height   = 'Height-mm (shell with meat)'
whole    = 'Whole-g (entire specimen)'
shucked  = 'Shucked-g (meat)'
viscera  = 'Viscera-g (gut after bleeding)'
shell    = 'Shell-g (dry)'

# %% [markdown]
# &nbsp;

# %% [markdown]
# ### 5.b. Specimen Length Against Ring Count:

# %%
data.groupby('Rings Count')[[length]].max()
# Out:
#              Length of Shell-mm (longest)
# Rings Count
# 1                                   0.075
# 2                                   0.150
# 3                                   0.240
# 4                                   0.360
# 5                                   0.440
# 6                                   0.660
# 7                                   0.720
# 8                                   0.720
# 9                                   0.745
# 10                                  0.770
# 11                                  0.780
# 12                                  0.775
# 13                                  0.760
# 14                                  0.815
# 15                                  0.710
# 16                                  0.740
# 17                                  0.775
# 18                                  0.745
# 19                                  0.705
# 20                                  0.725
# 21                                  0.735
# 22                                  0.655
# 23                                  0.800
# 24                                  0.700
# 25                                  0.645
# 26                                  0.600
# 27                                  0.665
# 29                                  0.700

# %%
sns.set(style="darkgrid")
plt.style.use('ggplot')
fig, ax = plt.subplots(nrows=2, ncols=1)
fig.subplots_adjust(hspace=-1.0)
plt.plot(data.groupby('Rings Count')[[length]].max(), color='violet')
ax[1].set_title('Lengths-mm')
ax[0].axis('off')
print()
print()

# %% [markdown]
# &nbsp;

# %% [markdown]
# This looks plausible with the length increasing rapidly with ring count for younger specimens and then leveling off into static.  Now to plot all of the measured columns for maximums and minimums grouped by ring count:

# %% [markdown]
# &nbsp;

# %%
fig, axis = plt.subplots(nrows=4, ncols=2, figsize=(15,20))
fig.suptitle('100 and 0 percentile readings grouped by Rings Count', fontsize=25)
fig.subplots_adjust(hspace=0.5)
axis[3, 1].axis('off')

labels_list = ['lengths (mm)', 'diameters (mm)', 'heights (mm)', 'whole (g)', 'shucked (g)', 'viscera (g)', 'shell (g)']
iterator = 0
i = 0
j = 0
for value in data.columns[1:8]:
    data.rename(columns = {value:'max'}, inplace = True)
    data.groupby('Rings Count')[['max']].max().plot(title = labels_list[iterator], ax = axis[i][j], color = 'red')
    data.rename(columns = {'max':'min'}, inplace = True) 
    data.groupby('Rings Count')[['min']].min().plot(ax = axis[i][j], color = 'black')
    data.rename(columns = {'min':value}, inplace = True)
    
    iterator += 1
    j = iterator%2
    i = iterator//2
    
for i in range(4):
    print()

# %% [markdown]
# &nbsp;

# %%
plt.rcParams['axes.facecolor'] = 'white'
plt.rcParams['grid.color'] = 'white'
plt.rcParams['grid.linestyle'] = '-'
plt.rcParams['grid.linewidth'] = 5.0
fig, axis = plt.subplots(1, figsize=(8,6))
fig.suptitle('Ring Count Distribution', fontsize=20)
axis.hist(data['Rings Count'], bins =10, color='black', zorder=-1)
axis.set_xlabel("Rings Counts", fontsize=15)
axis.grid(axis='x')
axis.tick_params(axis='x', labelsize=20)
axis.tick_params(axis='y', labelsize=15)
plt.show()

# %% [markdown]
# <br>

# %% [markdown]
# ### 5.c. Height Anomalies:

# %%
pd.DataFrame(data[height]).sort_values(by = height, ascending=False).head(10)
# Out:
#       Height-mm (shell with meat)
# 2051                        1.130
# 1417                        0.515
# 1763                        0.250
# 1428                        0.250
# 2179                        0.250
# 307                         0.240
# 1528                        0.240
# 277                         0.240
# 2161                        0.240
# 3993                        0.235

# %% [markdown]
# The top two heights are implausible.  The best way to handle this is to do a central tendency imputation using mean grouped by ring count.

# %%
data.loc[data['Rings Count'] == data.iloc[[1417],:]['Rings Count'].values[0] , :][height].mean()
# Out:
# 0.15409305993690883

# %%
data.loc[data.index == 1417, height] = 0.15409305993690883

# %%
data.loc[data.index == 1417, height].values[0]
# Out:
# 0.15409305993690883

# %%
data.loc[data['Rings Count'] == data.iloc[[2051],:]['Rings Count'].values[0] , :][height].mean()
# Out:
# 0.12855633802816907

# %%
data.loc[data.index == 2051, height] = 0.12855633802816907

# %%
data.loc[data.index == 2051, height].values[0]
# Out:
# 0.12855633802816907

# %%
pd.DataFrame(data[height]).sort_values(by = height, ascending=False).head(10)
# Out:
#       Height-mm (shell with meat)
# 2179                        0.250
# 1428                        0.250
# 1763                        0.250
# 2161                        0.240
# 307                         0.240
# 277                         0.240
# 1528                        0.240
# 2177                        0.235
# 506                         0.235
# 3993                        0.235

# %% [markdown]
# &nbsp;

# %% [markdown]
# Redoing the plot for height:

# %% [markdown]
# &nbsp;

# %%
sns.set(style="darkgrid")
plt.style.use('ggplot')
fig, axis = plt.subplots(1, figsize=(8,6))
data.rename(columns = {height:'max'}, inplace = True) 
data.groupby('Rings Count')[['max']].max().plot(title = 'heights (mm)', ax = axis, color = 'red')
data.rename(columns = {'max':'min'}, inplace = True) 
data.groupby('Rings Count')[['min']].min().plot(ax = axis, color = 'black')
data.rename(columns = {'min':height}, inplace = True)

# %% [markdown]
# &nbsp;

# %% [markdown]
# ### 5.d. Going Further into mm Measurements:

# %%
data.shape
# Out:
# (4177, 9)

# %%
data[data[length] > data[diameter]].shape
# Out:
# (4176, 9)

# %%
data[data[diameter] >= data[length]]
# Out:
#      Sex (M, F, and neutral)  Length of Shell-mm (longest)  \
# 1210                 neutral                         0.185
#
#       Diameter-mm (perpendicular to longest)  Height-mm (shell with meat)  \
# 1210                                   0.375                         0.12
#
#       Whole-g (entire specimen)  Shucked-g (meat)  \
# 1210                     0.4645             0.196
#
#       Viscera-g (gut after bleeding)  Shell-g (dry)  Rings Count
# 1210                          0.1045           0.15            6

# %% [markdown]
# &nbsp;

# %% [markdown]
# The diameter and length are inverted based on expectations set by the guide provided by the UCI Machine Learning Repository.  On this basis, the length should be the longer rather than the shorter of the two.  Replacing the one further from the average grouped by ring count:

# %% [markdown]
# &nbsp;

# %%
presumed_diameter=data.loc[data['Rings Count']==data.loc[data.index == 1210, 'Rings Count'].values[0] , :][diameter].mean()

# %%
presumed_diameter/0.375
# Out:
# 0.7436293436293439

# %%
presumed_length=data.loc[data['Rings Count'] == data.loc[data.index == 1210, 'Rings Count'].values[0] , :][length].mean()

# %%
presumed_length/0.185
# Out:
# 1.996556401961808

# %% [markdown]
# Replacing the length:

# %%
data.loc[data.index == 1210, length] = presumed_length

# %%
data.loc[data.index == 1210, length].values[0]
# Out:
# 0.3693629343629345

# %%
data[data[diameter] > data[height]].shape
# Out:
# (4177, 9)

# %%
data[data[height]==0]
# Out:
#      Sex (M, F, and neutral)  Length of Shell-mm (longest)  \
# 1257                 neutral                         0.430
# 3996                 neutral                         0.315
#
#       Diameter-mm (perpendicular to longest)  Height-mm (shell with meat)  \
# 1257                                    0.34                          0.0
# 3996                                    0.23                          0.0
#
#       Whole-g (entire specimen)  Shucked-g (meat)  \
# 1257                      0.428            0.2065
# 3996                      0.134            0.0575
#
#       Viscera-g (gut after bleeding)  Shell-g (dry)  Rings Count
# 1257                          0.0860         0.1150            8
# 3996                          0.0285         0.3505            6

# %%
data[length].describe()
# Out:
# count    4177.000000
# mean        0.524036
# std         0.120002
# min         0.075000
# 25%         0.450000
# 50%         0.545000
# 75%         0.615000
# max         0.815000
# Name: Length of Shell-mm (longest), dtype: float64

# %%
data[diameter].quantile(0.06)
# Out:
# 0.23

# %% [markdown]
# Samples 1257 and 3996 have 0 height even though a small but significant percentage (6%) of all samples are smaller in diameter.  Changing the height for both:

# %%
data.loc[data['Rings Count'] == 8][height].mean()
# Out:
# 0.12679323298948625

# %%
data.loc[data.index == 1257, height] = 0.12679323298948625

# %%
data.loc[data.index == 1257, height].values[0]
# Out:
# 0.12679323298948625

# %%
data.loc[data['Rings Count'] == 6][height].mean()
# Out:
# 0.09177606177606175

# %%
data.loc[data.index == 3996, height] = 0.09177606177606175

# %%
data.loc[data.index == 3996, height].values[0]
# Out:
# 0.09177606177606175

# %%
data[data[height]==0].shape
# Out:
# (0, 9)

# %% [markdown]
# Comparing diameter and height:

# %%
fig, axis = plt.subplots(1, figsize=(8,6))
fig.suptitle('Diameter to Height Ratio', fontsize=20)
axis.plot(data[diameter]/data[height], color = 'red', zorder=-1)
axis.set_xlabel("Diameter/Height", fontsize=15)
plt.rcParams['grid.color'] = 'white'
plt.show()

# %%
(data[diameter]/data[height]).sort_values(ascending=False).head(10)
# Out:
# 1174    33.000000
# 2169     7.666667
# 2801     6.437500
# 3902     6.000000
# 3190     5.800000
# 694      5.500000
# 236      5.500000
# 2782     5.333333
# 2172     5.000000
# 2558     4.769231
# dtype: float64

# %% [markdown]
# Let's look more closely at sample 1174:

# %%
data.iloc[[1174]][[diameter, height, 'Rings Count']]
# Out:
#       Diameter-mm (perpendicular to longest)  Height-mm (shell with meat)  \
# 1174                                   0.495                        0.015
#
#       Rings Count
# 1174            9

# %%
data[data['Rings Count'] == 9][height].mean()
# Out:
# 0.14272133526850514

# %%
data[data['Rings Count'] == 9][diameter].mean()
# Out:
# 0.4252177068214804

# %% [markdown]
# Changing the height:

# %%
data.loc[data.index == 1174, height] = 0.14272133526850514

# %%
data.loc[data.index == 1174, height].values[0]
# Out:
# 0.14272133526850514

# %%
(data[diameter]/data[height]).sort_values(ascending=False).head(10)
# Out:
# 2169    7.666667
# 2801    6.437500
# 3902    6.000000
# 3190    5.800000
# 694     5.500000
# 236     5.500000
# 2782    5.333333
# 2172    5.000000
# 2558    4.769231
# 2711    4.666667
# dtype: float64

# %% [markdown]
# &nbsp;

# %% [markdown]
# ### 5.e. Checking the Weights:

# %% [markdown]
# As a reminder:

# %%
data.head(0).T
# Out:
# Empty DataFrame
# Columns: []
# Index: [Sex (M, F, and neutral), Length of Shell-mm (longest), Diameter-mm (perpendicular to longest), Height-mm (shell with meat), Whole-g (entire specimen), Shucked-g (meat), Viscera-g (gut after bleeding), Shell-g (dry), Rings Count]

# %% [markdown]
# &nbsp;

# %% [markdown]
# Let's compare the whole weight with the sum of the other weight measurements.

# %% [markdown]
# &nbsp;

# %%
((data[shucked] +  data[viscera] + data[shell])/data[whole]).sort_values(ascending=False).head(20)
# Out:
# 2627    5.170616
# 1216    4.644550
# 3996    3.257463
# 2641    3.140684
# 2127    2.062992
# 3086    2.009804
# 3814    1.503093
# 236     1.500000
# 822     1.490909
# 1264    1.466398
# 2114    1.428571
# 2171    1.372881
# 193     1.372727
# 1430    1.349515
# 3518    1.331973
# 1219    1.284173
# 2790    1.277037
# 2084    1.269062
# 43      1.250000
# 1302    1.248049
# dtype: float64

# %%
((data[shucked] +  data[viscera] + data[shell])/data[whole]).sort_values().head(20)
# Out:
# 647     0.664093
# 1812    0.665421
# 3860    0.685305
# 2172    0.688312
# 831     0.697236
# 4052    0.698124
# 999     0.699822
# 1056    0.724138
# 270     0.724564
# 2240    0.729381
# 811     0.733723
# 3827    0.734081
# 694     0.736842
# 3800    0.744645
# 3837    0.750000
# 3143    0.750000
# 3396    0.755879
# 2528    0.761541
# 3522    0.763359
# 760     0.765619
# dtype: float64

# %%
fig, axis = plt.subplots(1, figsize=(8,6))
fig.suptitle('Weight Comparison Ratio', fontsize=20)
axis.plot((data[shucked] +  data[viscera] + data[shell])/data[whole], color='orange')
axis.set_xlabel("sum of partial weights/ whole weight", fontsize=15)
plt.show()

# %% [markdown]
# &nbsp;

# %% [markdown]
# How can the entire specimen be up to five times lighter than the sum of its components?  Or 25% heavier?

# %% [markdown]
# &nbsp;

# %%
(((data[shucked] +  data[viscera] + data[shell])/data[whole]) > 1).sum()
# Out:
# 155

# %%
(((data[shucked] +  data[viscera] + data[shell])/data[whole]) < 0.80).sum()
# Out:
# 43

# %%
data.shape
# Out:
# (4177, 9)

# %% [markdown]
# &nbsp;

# %% [markdown]
# These problems must be related to changes in moisture content at various times during the processing of the sample.  Better to drop the entire sample because none of the weights are valid.

# %% [markdown]
# &nbsp;

# %%
data.drop(data[(data[shucked] +  data[viscera] + data[shell])/data[whole] > 2.0].index, inplace=True)

# %% [markdown]
# Revisiting the histogram:

# %%
fig, axis = plt.subplots(1, figsize=(8,6))
fig.suptitle('Weight Comparison Ratio Revisited', fontsize=20)
axis.plot((data[shucked] +  data[viscera] + data[shell])/data[whole], color='#DEC20B')
axis.set_xlabel("whole weight/sum of partial weights", fontsize=15)
plt.show()

# %% [markdown]
# &nbsp;

# %% [markdown]
# ### 6. Gender and Ring Count (A Closer Look):

# %% [markdown]
# At this point, we are going to settle some questions regarding the designations, 'M', 'F' and 'neutral' as they relate to the numerical data fields.  Do they matter at all in this context?  As a preliminary analysis, let's make a table of means grouped by sex for each measurement in either millimeters or grams.

# %%
means = np.array([])
for outer_value in data.columns[1:8]:
    for inner_value in data[sex].unique():
        means = np.append (means, np.mean(data[data[sex] == inner_value][outer_value]))
means = np.reshape(means, [7, 3])
pd.concat([pd.DataFrame({'measurements' : data.columns[1:8]}), pd.DataFrame(means, columns = np.array(data[sex].\
                        unique()))], axis=1).style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_79275770_a649_11eb_9ff8_502f9bedf95d" ><thead>    <tr>        <th class="col_heading level0 col0" >measurements</th>        <th class="col_heading level0 col1" >M</th>        <th class="col_heading level0 col2" >F</th>        <th class="col_heading level0 col3" >neutral</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_79275770_a649_11eb_9ff8_502f9bedf95drow0_col0" class="data row0 col0" >Length of Shell-mm (longest)</td>
#                         <td id="T_79275770_a649_11eb_9ff8_502f9bedf95drow0_col1" class="data row0 col1" >0.561391</td>
#                         <td id="T_79275770_a649_11eb_9ff8_502f9bedf95drow0_col2" class="data row0 col2" >0.579093</td>
#                         <td id="T_79275770_a649_11eb_9ff8_502f9bedf95drow0_col3" class="data row0 col3" >0.428211</td>
#             </tr>
#             <tr>
#                                 <td id="T_79275770_a649_11eb_9ff8_502f9bedf95drow1_col0" class="data row1 col0" >Diameter-mm (perpendicular to longest)</td>
#                         <td id="T_79275770_a649_11eb_9ff8_502f9bedf95drow1_col1" class="data row1 col1" >0.439287</td>
#                         <td id="T_79275770_a649_11eb_9ff8_502f9bedf95drow1_col2" class="data row1 col2" >0.454732</td>
#                         <td id="T_79275770_a649_11eb_9ff8_502f9bedf95drow1_col3" class="data row1 col3" >0.326759</td>
#             </tr>
#             <tr>
#                                 <td id="T_79275770_a649_11eb_9ff8_502f9bedf95drow2_col0" class="data row2 col0" >Height-mm (shell with meat)</td>
#                         <td id="T_79275770_a649_11eb_9ff8_502f9bedf95drow2_col1" class="data row2 col1" >0.151145</td>
#                         <td id="T_79275770_a649_11eb_9ff8_502f9bedf95drow2_col2" class="data row2 col2" >0.157342</td>
#                         <td id="T_79275770_a649_11eb_9ff8_502f9bedf95drow2_col3" class="data row2 col3" >0.108265</td>
#             </tr>
#             <tr>
#                                 <td id="T_79275770_a649_11eb_9ff8_502f9bedf95drow3_col0" class="data row3 col0" >Whole-g (entire specimen)</td>
#                         <td id="T_79275770_a649_11eb_9ff8_502f9bedf95drow3_col1" class="data row3 col1" >0.991459</td>
#                         <td id="T_79275770_a649_11eb_9ff8_502f9bedf95drow3_col2" class="data row3 col2" >1.046532</td>
#                         <td id="T_79275770_a649_11eb_9ff8_502f9bedf95drow3_col3" class="data row3 col3" >0.432695</td>
#             </tr>
#             <tr>
#                                 <td id="T_79275770_a649_11eb_9ff8_502f9bedf95drow4_col0" class="data row4 col0" >Shucked-g (meat)</td>
#                         <td id="T_79275770_a649_11eb_9ff8_502f9bedf95drow4_col1" class="data row4 col1" >0.432946</td>
#                         <td id="T_79275770_a649_11eb_9ff8_502f9bedf95drow4_col2" class="data row4 col2" >0.446188</td>
#                         <td id="T_79275770_a649_11eb_9ff8_502f9bedf95drow4_col3" class="data row4 col3" >0.190695</td>
#             </tr>
#             <tr>
#                                 <td id="T_79275770_a649_11eb_9ff8_502f9bedf95drow5_col0" class="data row5 col0" >Viscera-g (gut after bleeding)</td>
#                         <td id="T_79275770_a649_11eb_9ff8_502f9bedf95drow5_col1" class="data row5 col1" >0.215545</td>
#                         <td id="T_79275770_a649_11eb_9ff8_502f9bedf95drow5_col2" class="data row5 col2" >0.230689</td>
#                         <td id="T_79275770_a649_11eb_9ff8_502f9bedf95drow5_col3" class="data row5 col3" >0.092223</td>
#             </tr>
#             <tr>
#                                 <td id="T_79275770_a649_11eb_9ff8_502f9bedf95drow6_col0" class="data row6 col0" >Shell-g (dry)</td>
#                         <td id="T_79275770_a649_11eb_9ff8_502f9bedf95drow6_col1" class="data row6 col1" >0.281969</td>
#                         <td id="T_79275770_a649_11eb_9ff8_502f9bedf95drow6_col2" class="data row6 col2" >0.302010</td>
#                         <td id="T_79275770_a649_11eb_9ff8_502f9bedf95drow6_col3" class="data row6 col3" >0.128242</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# &nbsp;

# %% [markdown]
# ### 6.a. Pearson Randomizations:

# %% [markdown]
# In each row, there are three numbers side by side.  The one in the middle is the largest and the one on the right is the smallest for every measurement in either millimeters or grams.  Following is a method for assigning a p value for any given row:
#
# 1) Compile another table with the same dimensions as the one above.  This time each entry is a Pearson Coefficient for a measured value against the ring count.
#
# 2) Compare entries on the same row, two at a time, each entry representing a specific dataset.  For each such comparison, subtract one of the two entries from the other.
#
# 3) Grouping by ring count, combine the two datasets formed in '2)' into one dataset.
#
# 4) Use np.random.permutation() to scramble up this dataset 10,000 times to see how often the difference calculated in '2)' is equaled or exceeded.  The number of times that this happens divided by 10,000 is the probability implied by the p-value.

# %%
pearson_array = np.array([])
for outer_value in data.columns[1:8]:
    for inner_value in data[sex].unique():
        pearson_array = np.append (pearson_array, np.corrcoef(data[data[sex] == inner_value][outer_value], \
                                                              data[data[sex] == inner_value]['Rings Count'])[0, 1])
pearson_array = np.reshape(pearson_array, [7, 3])
pd.concat([pd.DataFrame({'measurements' : data.columns[1:8]}), pd.DataFrame(pearson_array, columns = np.array(data[sex].\
                        unique()))], axis=1).style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_79301499_a649_11eb_a140_502f9bedf95d" ><thead>    <tr>        <th class="col_heading level0 col0" >measurements</th>        <th class="col_heading level0 col1" >M</th>        <th class="col_heading level0 col2" >F</th>        <th class="col_heading level0 col3" >neutral</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_79301499_a649_11eb_a140_502f9bedf95drow0_col0" class="data row0 col0" >Length of Shell-mm (longest)</td>
#                         <td id="T_79301499_a649_11eb_a140_502f9bedf95drow0_col1" class="data row0 col1" >0.366646</td>
#                         <td id="T_79301499_a649_11eb_a140_502f9bedf95drow0_col2" class="data row0 col2" >0.230610</td>
#                         <td id="T_79301499_a649_11eb_a140_502f9bedf95drow0_col3" class="data row0 col3" >0.685573</td>
#             </tr>
#             <tr>
#                                 <td id="T_79301499_a649_11eb_a140_502f9bedf95drow1_col0" class="data row1 col0" >Diameter-mm (perpendicular to longest)</td>
#                         <td id="T_79301499_a649_11eb_a140_502f9bedf95drow1_col1" class="data row1 col1" >0.388910</td>
#                         <td id="T_79301499_a649_11eb_a140_502f9bedf95drow1_col2" class="data row1 col2" >0.265888</td>
#                         <td id="T_79301499_a649_11eb_a140_502f9bedf95drow1_col3" class="data row1 col3" >0.694427</td>
#             </tr>
#             <tr>
#                                 <td id="T_79301499_a649_11eb_a140_502f9bedf95drow2_col0" class="data row2 col0" >Height-mm (shell with meat)</td>
#                         <td id="T_79301499_a649_11eb_a140_502f9bedf95drow2_col1" class="data row2 col1" >0.447609</td>
#                         <td id="T_79301499_a649_11eb_a140_502f9bedf95drow2_col2" class="data row2 col2" >0.342975</td>
#                         <td id="T_79301499_a649_11eb_a140_502f9bedf95drow2_col3" class="data row2 col3" >0.723966</td>
#             </tr>
#             <tr>
#                                 <td id="T_79301499_a649_11eb_a140_502f9bedf95drow3_col0" class="data row3 col0" >Whole-g (entire specimen)</td>
#                         <td id="T_79301499_a649_11eb_a140_502f9bedf95drow3_col1" class="data row3 col1" >0.372197</td>
#                         <td id="T_79301499_a649_11eb_a140_502f9bedf95drow3_col2" class="data row3 col2" >0.266759</td>
#                         <td id="T_79301499_a649_11eb_a140_502f9bedf95drow3_col3" class="data row3 col3" >0.695644</td>
#             </tr>
#             <tr>
#                                 <td id="T_79301499_a649_11eb_a140_502f9bedf95drow4_col0" class="data row4 col0" >Shucked-g (meat)</td>
#                         <td id="T_79301499_a649_11eb_a140_502f9bedf95drow4_col1" class="data row4 col1" >0.222394</td>
#                         <td id="T_79301499_a649_11eb_a140_502f9bedf95drow4_col2" class="data row4 col2" >0.094848</td>
#                         <td id="T_79301499_a649_11eb_a140_502f9bedf95drow4_col3" class="data row4 col3" >0.626956</td>
#             </tr>
#             <tr>
#                                 <td id="T_79301499_a649_11eb_a140_502f9bedf95drow5_col0" class="data row5 col0" >Viscera-g (gut after bleeding)</td>
#                         <td id="T_79301499_a649_11eb_a140_502f9bedf95drow5_col1" class="data row5 col1" >0.320954</td>
#                         <td id="T_79301499_a649_11eb_a140_502f9bedf95drow5_col2" class="data row5 col2" >0.211615</td>
#                         <td id="T_79301499_a649_11eb_a140_502f9bedf95drow5_col3" class="data row5 col3" >0.672385</td>
#             </tr>
#             <tr>
#                                 <td id="T_79301499_a649_11eb_a140_502f9bedf95drow6_col0" class="data row6 col0" >Shell-g (dry)</td>
#                         <td id="T_79301499_a649_11eb_a140_502f9bedf95drow6_col1" class="data row6 col1" >0.510997</td>
#                         <td id="T_79301499_a649_11eb_a140_502f9bedf95drow6_col2" class="data row6 col2" >0.405907</td>
#                         <td id="T_79301499_a649_11eb_a140_502f9bedf95drow6_col3" class="data row6 col3" >0.728407</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# &nbsp;

# %% [markdown]
# The relationship between the three columns is the reverse of what applies to the means which underscores the importance of specimen sex.  A low p-value is therefor expected.  Starting with a comparison of the 'M' and 'F' columns, let's combine the measurements and ring counts for 'Shucked-g (meat)':

# %% [markdown]
# &nbsp;

# %%
shucked_mf = pd.concat([data[data[sex]=='M'][[shucked, 'Rings Count']], data[data[sex]=='F'][[shucked, 'Rings Count']]],\
                      axis=0)

# %%
shucked_mf.shape
# Out:
# (2835, 2)

# %% [markdown]
# Verifying that the shape is right:

# %%
data[data[sex]=='M'][[shucked, 'Rings Count']].shape, data[data[sex]=='F'][[shucked, 'Rings Count']].shape
# Out:
# ((1528, 2), (1307, 2))

# %% [markdown]
# Now for an array of pairs, one for male and one for female:

# %%
array_calculations = np.array([])
sample_size = 10000
for i in range (sample_size):
    sample = np.random.permutation(shucked_mf)
    array_calculations=np.append(array_calculations, [np.corrcoef(sample[0:1527, 0], sample[0:1527 ,1])[0,1],\
                                                      np.corrcoef(sample[1527:2835, 0], sample[1527:2835 ,1])[0,1]])
array_calculations = np.reshape(array_calculations, [sample_size, 2])
array_calculations[:10]
# Out:
# array([[0.16695736, 0.17133731],
#        [0.16343386, 0.1729052 ],
#        [0.17142841, 0.16547018],
#        [0.16307946, 0.17399276],
#        [0.16932362, 0.16705324],
#        [0.17281744, 0.16221443],
#        [0.15462536, 0.18279692],
#        [0.15231074, 0.18521013],
#        [0.11913677, 0.22630814],
#        [0.16813187, 0.16720045]])

# %% [markdown]
# &nbsp;

# %% [markdown]
# Next, see how many times these rows differ by at least the result of subtracting the female Pearson coefficient from the male for 'Shucked-g (meat)' tabulated above.  To answer that question and get the p-value, take the sum of array_calculation[i, 0] - array_calculation[i, 1] >= 0.222394 - 0.094848.  ('0.222394 - 0.094848' is taken directly off of the table.)

# %% [markdown]
# &nbsp;

# %%
pearson_differences = np.array([])
for pair in array_calculations:
    pearson_differences = np.append(pearson_differences, pair[0] - pair[1])
print(np.sum(pearson_differences >= pearson_array[4,0] - pearson_array[4,1]))
np.max(pearson_differences)
# Out:
# 1
# 0.14859115080672375

# %%
pearson_array[4,0] - pearson_array[4,1]
# Out:
# 0.12754579146221356

# %% [markdown]
# &nbsp;

# %% [markdown]
# There was only one case out of 10,000 in which the difference in Pearson coefficient values is greater than the result obtained by subtracting off of the table (as explained above).  Dividing by 100 (which is the same as multiplying by 100 to get a percentage and than dividing by 10,000 for the sample size), the p-value is shown to be 0.01, further supporting the significance of 'M' and 'F'.

# %% [markdown]
# &nbsp;

# %% [markdown]
# ### 6.b.  'p' Value from Weights:

# %% [markdown]
# Now to compare the male and neutral values for 'Viscera-g (gut after bleeding)'.

# %% [markdown]
# &nbsp;

# %%
viscera_neutralM = pd.concat([data[data[sex]=='neutral'][[viscera, 'Rings Count']],\
                              data[data[sex]=='M'][[viscera, 'Rings Count']]], axis=0)

# %%
viscera_neutralM.shape
# Out:
# (2864, 2)

# %% [markdown]
# Checking shape:

# %%
data[data[sex]=='neutral'][[viscera, 'Rings Count']].shape, data[data[sex]=='M'][[viscera, 'Rings Count']].shape
# Out:
# ((1336, 2), (1528, 2))

# %% [markdown]
# &nbsp;

# %%
array_calculations = np.array([])
sample_size = 10000
for i in range (sample_size):
    sample = np.random.permutation(viscera_neutralM)
    array_calculations=np.append(array_calculations, [np.corrcoef(sample[0:1336, 0], sample[0:1336 ,1])[0,1],\
                                                      np.corrcoef(sample[1336:, 0], sample[1336: ,1])[0,1]])
array_calculations = np.reshape(array_calculations, [sample_size, 2])
array_calculations[:10]
# Out:
# array([[0.56835807, 0.56404763],
#        [0.56466862, 0.56747129],
#        [0.56716197, 0.56500584],
#        [0.59109232, 0.5463247 ],
#        [0.57207493, 0.5613016 ],
#        [0.55968862, 0.57286661],
#        [0.56248693, 0.56912952],
#        [0.5639519 , 0.56792182],
#        [0.55781551, 0.57368604],
#        [0.57451604, 0.55892928]])

# %%
pearson_differences = np.array([])
for pair in array_calculations:
    pearson_differences = np.append(pearson_differences, pair[0] - pair[1])
print(np.sum(pearson_differences >= pearson_array[5,2] - pearson_array[5,0]))
np.max(pearson_differences)
# Out:
# 0
# 0.12585455623457975

# %%
pearson_array[5,2] - pearson_array[5,0]
# Out:
# 0.3514310865350725

# %% [markdown]
# The p-value is 0 thus establishing a significant difference between a sample being marked 'M' verses neutral.  Conclusion: Sex will have to be factored in to any predictive model relating measurements to ring counts.

# %% [markdown]
# &nbsp;

# %% [markdown]
# ### 7.  Export to CSV File:

# %% [markdown]
# We are cleaning up the indexing of the main data frame and then exporting it to a csv file for the 'abalone analysis' notebook.

# %%
data.reset_index(drop=True, inplace=True)

# %%
data.index, data.index.values.shape
# Out:
# (RangeIndex(start=0, stop=4171, step=1), (4171,))

# %%
data.head().style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_ca62ece4_a92e_11eb_9007_502f9bedf95d" ><thead>    <tr>        <th class="col_heading level0 col0" >Sex (M, F, and neutral)</th>        <th class="col_heading level0 col1" >Length of Shell-mm (longest)</th>        <th class="col_heading level0 col2" >Diameter-mm (perpendicular to longest)</th>        <th class="col_heading level0 col3" >Height-mm (shell with meat)</th>        <th class="col_heading level0 col4" >Whole-g (entire specimen)</th>        <th class="col_heading level0 col5" >Shucked-g (meat)</th>        <th class="col_heading level0 col6" >Viscera-g (gut after bleeding)</th>        <th class="col_heading level0 col7" >Shell-g (dry)</th>        <th class="col_heading level0 col8" >Rings Count</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_ca62ece4_a92e_11eb_9007_502f9bedf95drow0_col0" class="data row0 col0" >M</td>
#                         <td id="T_ca62ece4_a92e_11eb_9007_502f9bedf95drow0_col1" class="data row0 col1" >0.455000</td>
#                         <td id="T_ca62ece4_a92e_11eb_9007_502f9bedf95drow0_col2" class="data row0 col2" >0.365000</td>
#                         <td id="T_ca62ece4_a92e_11eb_9007_502f9bedf95drow0_col3" class="data row0 col3" >0.095000</td>
#                         <td id="T_ca62ece4_a92e_11eb_9007_502f9bedf95drow0_col4" class="data row0 col4" >0.514000</td>
#                         <td id="T_ca62ece4_a92e_11eb_9007_502f9bedf95drow0_col5" class="data row0 col5" >0.224500</td>
#                         <td id="T_ca62ece4_a92e_11eb_9007_502f9bedf95drow0_col6" class="data row0 col6" >0.101000</td>
#                         <td id="T_ca62ece4_a92e_11eb_9007_502f9bedf95drow0_col7" class="data row0 col7" >0.150000</td>
#                         <td id="T_ca62ece4_a92e_11eb_9007_502f9bedf95drow0_col8" class="data row0 col8" >15</td>
#             </tr>
#             <tr>
#                                 <td id="T_ca62ece4_a92e_11eb_9007_502f9bedf95drow1_col0" class="data row1 col0" >M</td>
#                         <td id="T_ca62ece4_a92e_11eb_9007_502f9bedf95drow1_col1" class="data row1 col1" >0.350000</td>
#                         <td id="T_ca62ece4_a92e_11eb_9007_502f9bedf95drow1_col2" class="data row1 col2" >0.265000</td>
#                         <td id="T_ca62ece4_a92e_11eb_9007_502f9bedf95drow1_col3" class="data row1 col3" >0.090000</td>
#                         <td id="T_ca62ece4_a92e_11eb_9007_502f9bedf95drow1_col4" class="data row1 col4" >0.225500</td>
#                         <td id="T_ca62ece4_a92e_11eb_9007_502f9bedf95drow1_col5" class="data row1 col5" >0.099500</td>
#                         <td id="T_ca62ece4_a92e_11eb_9007_502f9bedf95drow1_col6" class="data row1 col6" >0.048500</td>
#                         <td id="T_ca62ece4_a92e_11eb_9007_502f9bedf95drow1_col7" class="data row1 col7" >0.070000</td>
#                         <td id="T_ca62ece4_a92e_11eb_9007_502f9bedf95drow1_col8" class="data row1 col8" >7</td>
#             </tr>
#             <tr>
#                                 <td id="T_ca62ece4_a92e_11eb_9007_502f9bedf95drow2_col0" class="data row2 col0" >F</td>
#                         <td id="T_ca62ece4_a92e_11eb_9007_502f9bedf95drow2_col1" class="data row2 col1" >0.530000</td>
#                         <td id="T_ca62ece4_a92e_11eb_9007_502f9bedf95drow2_col2" class="data row2 col2" >0.420000</td>
#                         <td id="T_ca62ece4_a92e_11eb_9007_502f9bedf95drow2_col3" class="data row2 col3" >0.135000</td>
#                         <td id="T_ca62ece4_a92e_11eb_9007_502f9bedf95drow2_col4" class="data row2 col4" >0.677000</td>
#                         <td id="T_ca62ece4_a92e_11eb_9007_502f9bedf95drow2_col5" class="data row2 col5" >0.256500</td>
#                         <td id="T_ca62ece4_a92e_11eb_9007_502f9bedf95drow2_col6" class="data row2 col6" >0.141500</td>
#                         <td id="T_ca62ece4_a92e_11eb_9007_502f9bedf95drow2_col7" class="data row2 col7" >0.210000</td>
#                         <td id="T_ca62ece4_a92e_11eb_9007_502f9bedf95drow2_col8" class="data row2 col8" >9</td>
#             </tr>
#             <tr>
#                                 <td id="T_ca62ece4_a92e_11eb_9007_502f9bedf95drow3_col0" class="data row3 col0" >M</td>
#                         <td id="T_ca62ece4_a92e_11eb_9007_502f9bedf95drow3_col1" class="data row3 col1" >0.440000</td>
#                         <td id="T_ca62ece4_a92e_11eb_9007_502f9bedf95drow3_col2" class="data row3 col2" >0.365000</td>
#                         <td id="T_ca62ece4_a92e_11eb_9007_502f9bedf95drow3_col3" class="data row3 col3" >0.125000</td>
#                         <td id="T_ca62ece4_a92e_11eb_9007_502f9bedf95drow3_col4" class="data row3 col4" >0.516000</td>
#                         <td id="T_ca62ece4_a92e_11eb_9007_502f9bedf95drow3_col5" class="data row3 col5" >0.215500</td>
#                         <td id="T_ca62ece4_a92e_11eb_9007_502f9bedf95drow3_col6" class="data row3 col6" >0.114000</td>
#                         <td id="T_ca62ece4_a92e_11eb_9007_502f9bedf95drow3_col7" class="data row3 col7" >0.155000</td>
#                         <td id="T_ca62ece4_a92e_11eb_9007_502f9bedf95drow3_col8" class="data row3 col8" >10</td>
#             </tr>
#             <tr>
#                                 <td id="T_ca62ece4_a92e_11eb_9007_502f9bedf95drow4_col0" class="data row4 col0" >neutral</td>
#                         <td id="T_ca62ece4_a92e_11eb_9007_502f9bedf95drow4_col1" class="data row4 col1" >0.330000</td>
#                         <td id="T_ca62ece4_a92e_11eb_9007_502f9bedf95drow4_col2" class="data row4 col2" >0.255000</td>
#                         <td id="T_ca62ece4_a92e_11eb_9007_502f9bedf95drow4_col3" class="data row4 col3" >0.080000</td>
#                         <td id="T_ca62ece4_a92e_11eb_9007_502f9bedf95drow4_col4" class="data row4 col4" >0.205000</td>
#                         <td id="T_ca62ece4_a92e_11eb_9007_502f9bedf95drow4_col5" class="data row4 col5" >0.089500</td>
#                         <td id="T_ca62ece4_a92e_11eb_9007_502f9bedf95drow4_col6" class="data row4 col6" >0.039500</td>
#                         <td id="T_ca62ece4_a92e_11eb_9007_502f9bedf95drow4_col7" class="data row4 col7" >0.055000</td>
#                         <td id="T_ca62ece4_a92e_11eb_9007_502f9bedf95drow4_col8" class="data row4 col8" >7</td>
#             </tr>
#     </tbody></table>

# %%
data.to_csv('data_cleaned.csv')

# %% [markdown]
# ### 8. Conclusion:

# %% [markdown]
# The data will be ready for machine learning when specimen sex is broken out numerically.
